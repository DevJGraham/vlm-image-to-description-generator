# %% [markdown]
# # Categorize Items
# This file takes the baseline descriptions and categorizes them into 1-2 word categories so that the performance of the model can be analyzed per category

# %% [markdown]
# ## Import Mistral-7B

# %%
from google.colab import drive
import pandas as pd

# %%
from transformers import pipeline

# %% [markdown]
# > Set `DIR` to where the data are stored for reading and writing to the directory

# %%
DIR = 'path-to-directory-in-drive'

# %%
drive.mount('/content/drive')

# %cd "$DIR"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CS/WGU/Computer Science Capstone - C964/vlm-image-to-description-generator/data

# %%
# !hf auth login

# %%
# Use a GPU when loading this model
from transformers import pipeline

pipe = pipeline("text-generation", model="mistralai/Mistral-7B-v0.1")

# %% [markdown]
# ## Read in baseline descriptions

# %%
df = (
  pd.read_csv("baseline_descriptions.csv", index_col=0)
)

df.head()
# Out:
#    item_number                                        Description
# 0            1  Impact-branded photo backdrop kit including a ...
# 1            2  Interfit Stellar X flash lighting unit with ad...
# 2            3  Interfit Stellar X 300 studio strobe light wit...
# 3            4  Interfit Stellar X 300 studio flash unit equip...
# 4            5  Interfit COR 751 lighting kit with a wheeled c...

# %% [markdown]
# ## Define labeling instructions for model

# %%
def label_descriptions(data):
  min_item = data['item_number'].min()
  max_item = data['item_number'].max()

  for item in range(min_item, max_item + 1):
    row = data[data['item_number'] == item].iloc[0]
    description = row['Description']

    prompt = f"""
    You are categorizing auction items.

    Task:
    - Output exactly one category name.
    - The category must be 1–3 words only.
    - It must be a generic, broad category (e.g., "Photography Equipment", "Furniture", "Tools").
    - Do not provide multiple categories, alternatives, or synonyms.
    - Do not use parentheses, slashes, or the word "or".
    - Answer only with the category name. No explanation, no punctuation, no extra text.

    Description:
    {description}
    Answer:"""

    result = pipe(
    prompt,
    max_new_tokens=20,
    do_sample=False,
    return_full_text=False,
    eos_token_id=pipe.tokenizer.eos_token_id,
    stop_sequence="Description:"
    )

    raw = result[0]["generated_text"]
    category = next((line.strip() for line in raw.split("\n") if line.strip()), "")

    data.loc[data['item_number'] == item, 'category'] = category

# %%
label_descriptions(df)

# %%
df
# Out:
#     item_number                                        Description  \
# 0             1  Impact-branded photo backdrop kit including a ...
# 1             2  Interfit Stellar X flash lighting unit with ad...
# 2             3  Interfit Stellar X 300 studio strobe light wit...
# 3             4  Interfit Stellar X 300 studio flash unit equip...
# 4             5  Interfit COR 751 lighting kit with a wheeled c...
# 5             6  Pair of Impact floodlight fixtures mounted on ...
# 6             7  Assorted hand tool collection including Sears ...
# 7             8  Box of assorted hand tools including multiple ...
# 8             9  Clear storage bin filled with grinding and cut...
# 9            10  Heavy-duty Armstrong slide hammer puller set, ...
# 10           11  Pittsburgh Automotive Bearing Race and Seal Dr...
# 11           12  Set of Snap-on deep impact sockets stored in a...
# 12           13  Set of Craftsman hand tools including two comp...
# 13           14  Set of nine Proto Professional chrome sockets,...
# 14           15  Set of two torque wrenches from KD Tools and C...
# 15           16  Collection of measuring and leveling tools inc...
# 16           17  Pair of heavy-duty Haul-Master steel loading r...
# 17           18  Collection of Dyson V8 cordless vacuum parts a...
# 18           19  Sculptural metal table lamp with welded abstra...
# 19           20  Tall mid-century lamp with stacked wood segmen...
# 20           21  Mid-century ceramic table lamp by Jacques Pouc...
# 21           22  Oil painting still life featuring a green wine...
# 22           23  Original painting by Ronald Bouché depicting a...
# 23           24  Colorful seascape painting signed “Dany ’03” f...
# 24           25  Vibrant painting by M.VinLouis, featuring an e...
# 25           26  Colorful oil painting of a cobblestone street ...
# 26           27  Colorful market scene painting signed by M. V....
# 27           28  Framed satirical courtroom prints, including "...
# 28           29  Round glass-top coffee table with a sculptural...
# 29           30   Mobile teak table with chrome pedestal base a...
# 30           31  Mid-century modern lounge chair featuring scul...
# 31           32  Two ceramic tiles: one with a delicate pastel ...
# 32           33  Mid-century Drexel dresser with a sleek walnut...
# 33           34  Low-profile coffee table featuring a rectangul...
# 34           35  Tall wooden case clock with an arched bonnet a...
# 35           36  Gothic-style antique mantel clock with a dark ...
# 36           37  Red Le Creuset terrine dish with a cream inter...
# 37           38  Handcrafted model of the Mayflower marked “162...
# 38           39  Green ceramic pitcher with carved leaf motif a...
# 39           40  Handcrafted metal angel wall hanging with intr...
# 40           41  Mr. Coffee Café Barista espresso machine with ...
# 41           42  Set of three decorative swords, each marked “T...
# 42           43  Ornate handwoven area rug with a raised floral...
# 43           44  Hand-tufted Royal Ashan area rug by Downs Carp...
# 44           45  Handwoven wool rug from the Soumak Collection,...
# 45           46  Set of three All-Clad stainless steel pans, in...
# 46           47  Towel Sterling silver flatware set in the 1973...
# 47           48  Pair of rectangular sterling silver military c...
# 48           49  Kenmore Elite electric dryer, model 110.669425...
# 49           50  CST/Berger Universal Contractor's Aluminum Tri...
# 50           51  Delta Sawbuck frame and trim saw, model 33-150...
# 51           52  Troy-Bilt 4-cycle gas-powered cultivator with ...
# 52           53  Snapper 22-inch self-propelled walk-behind mow...
# 53           54  Pair of vintage metal mechanical banks designe...
# 54           55  Framed Bob Dylan collector's set featuring a l...
# 55           56  Husqvarna 136LE chainsaw powered by a 36cc 2-c...
# 56           57  Vintage Lionel Lines O-gauge electric train se...
# 57           58  Hitachi NT65MA2 2-1/2” finish nailer with angl...
# 58           59  Pair of Continental ProContact TX tires, size ...
# 59           60  Set of two space heaters including a LifeSmart...
#
#                   category
# 0    Photography Equipment
# 1    Photography Equipment
# 2    Photography Equipment
# 3    Photography Equipment
# 4    Photography Equipment
# 5    Photography Equipment
# 6                    Tools
# 7                    Tools
# 8             Metalworking
# 9                    Tools
# 10                   Tools
# 11                   Tools
# 12                   Tools
# 13                   Tools
# 14                   Tools
# 15                   Tools
# 16                   Tools
# 17                   Tools
# 18                Lighting
# 19                Lighting
# 20               Furniture
# 21                     Art
# 22                     Art
# 23                     Art
# 24                     Art
# 25                     Art
# 26                     Art
# 27                     Art
# 28               Furniture
# 29               Furniture
# 30               Furniture
# 31                Ceramics
# 32               Furniture
# 33               Furniture
# 34                  Clocks
# 35                  Clocks
# 36                Cookware
# 37                Antiques
# 38         Decorative Arts
# 39      Metal Wall Hanging
# 40            Coffee Maker
# 41       Decorative Swords
# 42                    Rugs
# 43               Furniture
# 44                    Rugs
# 45                Cookware
# 46               Furniture
# 47                 Jewelry
# 48              Appliances
# 49  Construction Equipment
# 50                   Tools
# 51            Garden Tools
# 52             Lawn Mowers
# 53                   Space
# 54                   Music
# 55             Power Tools
# 56               Train Set
# 57                   Tools
# 58                   Tires
# 59       Heating Equipment

# %% [markdown]
# ## Correct some categories by hand

# %%
def correct_categories(df, corrections):
  for item_number, category in corrections:
    df.loc[df['item_number'] == item_number, 'category'] = category
  return df

# %%
corrections = [
  (9, 'Tools'),
  (21, 'Lighting'),
  (32, 'Art'),
  (38, 'Collectibles'),
  (39, 'Art'),
  (40, 'Decorative'),
  (41, 'Kitchen Appliance'),
  (42, 'Decorative'),
  (44, 'Rugs'),
  (47, 'Flatware'),
  (50, 'Tools'),
  (53, 'Tools'),
  (54, 'Collectibles'),
  (55, 'Collectibles'),
  (57, 'Collectibles'),
  (56, 'Tools')
]

df = correct_categories(df, corrections)

# %%
df
# Out:
#     item_number                                        Description  \
# 0             1  Impact-branded photo backdrop kit including a ...
# 1             2  Interfit Stellar X flash lighting unit with ad...
# 2             3  Interfit Stellar X 300 studio strobe light wit...
# 3             4  Interfit Stellar X 300 studio flash unit equip...
# 4             5  Interfit COR 751 lighting kit with a wheeled c...
# 5             6  Pair of Impact floodlight fixtures mounted on ...
# 6             7  Assorted hand tool collection including Sears ...
# 7             8  Box of assorted hand tools including multiple ...
# 8             9  Clear storage bin filled with grinding and cut...
# 9            10  Heavy-duty Armstrong slide hammer puller set, ...
# 10           11  Pittsburgh Automotive Bearing Race and Seal Dr...
# 11           12  Set of Snap-on deep impact sockets stored in a...
# 12           13  Set of Craftsman hand tools including two comp...
# 13           14  Set of nine Proto Professional chrome sockets,...
# 14           15  Set of two torque wrenches from KD Tools and C...
# 15           16  Collection of measuring and leveling tools inc...
# 16           17  Pair of heavy-duty Haul-Master steel loading r...
# 17           18  Collection of Dyson V8 cordless vacuum parts a...
# 18           19  Sculptural metal table lamp with welded abstra...
# 19           20  Tall mid-century lamp with stacked wood segmen...
# 20           21  Mid-century ceramic table lamp by Jacques Pouc...
# 21           22  Oil painting still life featuring a green wine...
# 22           23  Original painting by Ronald Bouché depicting a...
# 23           24  Colorful seascape painting signed “Dany ’03” f...
# 24           25  Vibrant painting by M.VinLouis, featuring an e...
# 25           26  Colorful oil painting of a cobblestone street ...
# 26           27  Colorful market scene painting signed by M. V....
# 27           28  Framed satirical courtroom prints, including "...
# 28           29  Round glass-top coffee table with a sculptural...
# 29           30   Mobile teak table with chrome pedestal base a...
# 30           31  Mid-century modern lounge chair featuring scul...
# 31           32  Two ceramic tiles: one with a delicate pastel ...
# 32           33  Mid-century Drexel dresser with a sleek walnut...
# 33           34  Low-profile coffee table featuring a rectangul...
# 34           35  Tall wooden case clock with an arched bonnet a...
# 35           36  Gothic-style antique mantel clock with a dark ...
# 36           37  Red Le Creuset terrine dish with a cream inter...
# 37           38  Handcrafted model of the Mayflower marked “162...
# 38           39  Green ceramic pitcher with carved leaf motif a...
# 39           40  Handcrafted metal angel wall hanging with intr...
# 40           41  Mr. Coffee Café Barista espresso machine with ...
# 41           42  Set of three decorative swords, each marked “T...
# 42           43  Ornate handwoven area rug with a raised floral...
# 43           44  Hand-tufted Royal Ashan area rug by Downs Carp...
# 44           45  Handwoven wool rug from the Soumak Collection,...
# 45           46  Set of three All-Clad stainless steel pans, in...
# 46           47  Towel Sterling silver flatware set in the 1973...
# 47           48  Pair of rectangular sterling silver military c...
# 48           49  Kenmore Elite electric dryer, model 110.669425...
# 49           50  CST/Berger Universal Contractor's Aluminum Tri...
# 50           51  Delta Sawbuck frame and trim saw, model 33-150...
# 51           52  Troy-Bilt 4-cycle gas-powered cultivator with ...
# 52           53  Snapper 22-inch self-propelled walk-behind mow...
# 53           54  Pair of vintage metal mechanical banks designe...
# 54           55  Framed Bob Dylan collector's set featuring a l...
# 55           56  Husqvarna 136LE chainsaw powered by a 36cc 2-c...
# 56           57  Vintage Lionel Lines O-gauge electric train se...
# 57           58  Hitachi NT65MA2 2-1/2” finish nailer with angl...
# 58           59  Pair of Continental ProContact TX tires, size ...
# 59           60  Set of two space heaters including a LifeSmart...
#
#                  category
# 0   Photography Equipment
# 1   Photography Equipment
# 2   Photography Equipment
# 3   Photography Equipment
# 4   Photography Equipment
# 5   Photography Equipment
# 6                   Tools
# 7                   Tools
# 8                   Tools
# 9                   Tools
# 10                  Tools
# 11                  Tools
# 12                  Tools
# 13                  Tools
# 14                  Tools
# 15                  Tools
# 16                  Tools
# 17                  Tools
# 18               Lighting
# 19               Lighting
# 20               Lighting
# 21                    Art
# 22                    Art
# 23                    Art
# 24                    Art
# 25                    Art
# 26                    Art
# 27                    Art
# 28              Furniture
# 29              Furniture
# 30              Furniture
# 31                    Art
# 32              Furniture
# 33              Furniture
# 34                 Clocks
# 35                 Clocks
# 36               Cookware
# 37           Collectibles
# 38                    Art
# 39             Decorative
# 40      Kitchen Appliance
# 41             Decorative
# 42                   Rugs
# 43                   Rugs
# 44                   Rugs
# 45               Cookware
# 46               Flatware
# 47                Jewelry
# 48             Appliances
# 49                  Tools
# 50                  Tools
# 51           Garden Tools
# 52                  Tools
# 53           Collectibles
# 54           Collectibles
# 55                  Tools
# 56           Collectibles
# 57                  Tools
# 58                  Tires
# 59      Heating Equipment

# %% [markdown]
# ## Save data to csv file in the data folder

# %%
df.to_csv('auction_13_categories.csv')
