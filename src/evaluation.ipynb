# %% [markdown]
# # Evaluation & Categorizing Descriptions
#
# This file takes in the model-generated descriptions, the baseline descriptions, as well as the categories of the items.
#
# A human labeler will randomly and anonymously be given the model and baseline descriptions and evalute the descriptions. The evaluation options are as follows:
# - Description 1 better
# - Description 2 better
# - Both good
# - Both bad
#
# The model will than be evaluated for how well it performed, as well as a more granular dive into how well it performed across the different categories of items.

# %% [markdown]
# ## Installs and Imports

# %%
from google.colab import drive
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import textwrap
from IPython.display import clear_output
from time import sleep
import random

# %% [markdown]
# > Set `DIR` to the directory where data are stored so that they can be read in

# %%
DIR = 'path-to-directory-in-drive'

# %%
# Mount Google Drive
drive.mount('/content/drive')

# %cd "$DIR"

# %% [markdown]
# # Read in the model and the baseline descriptions

# %% [markdown]
# ## Model descriptions

# %%
model_df = pd.read_csv('aypt2025-13_descriptions.csv', index_col=0)

# %%
model_df.head()
# Out:
#    item_number                                               text  \
# 0            1  ['impact', 'impact', 'FLEXIBLE TO', 'FLEXIBLE'...
# 1            2  ['INTERIIT', 'INTERIIT', 'INTERFIT', 'INTERFIT...
# 2            3  ['INTERFIT\nStellar', 'INTERFIT', 'Stellar', '...
# 3            4  ['INTERFIT\nStellar', 'INTERFIT', 'Stellar', '...
# 4            5  ['INTERFIT', 'INTERFIT', 'INTERFIT', 'INTERFIT...
#
#                                               labels                 objects  \
# 0  ['Tripod', 'Bag', 'Baggage', 'Cameras & optics...                      []
# 1  ['Electronic device', 'Microphone stand', 'Ele...              ['Tripod']
# 2  ['Electronic device', 'Cameras & optics', 'Ele...  ['Lighting', 'Tripod']
# 3  ['Electronic device', 'Electrical cable', 'Cam...  ['Tripod', 'Lighting']
# 4                                        ['Balance']                 ['Hat']
#
#         thumbnail_path                                         model_desc
# 0  aypt2025-13/1_1.jpg  High-quality camera equipment set, including t...
# 1  aypt2025-13/2_1.jpg  Professional-grade INTERFIT Stellaro sound mod...
# 2  aypt2025-13/3_1.jpg  Professional-grade grey overhead projector wit...
# 3  aypt2025-13/4_1.jpg  Professional-grade Interfit Stellar 300 lighti...
# 4  aypt2025-13/5_1.jpg  Black circular cap with "INTERFIT" text in whi...

# %%
# Example of auction description
model_df[model_df['item_number']==44]['model_desc'].iloc[0]
# Out:
# 'Elegant vintage prayer rug featuring a rich gold and brown floral design with intricate patterns. Made from pure wool, showcasing exceptional craftsmanship. Measures 4\'6" x 6\', perfect for adding sophistication to any living space.'

# %% [markdown]
# ## Baseline Descriptions

# %%
baseline_df = (
  pd.read_csv('baseline_descriptions.csv', index_col=0)
  .rename(columns={"Description": "baseline_desc"})
  .assign(item_number=lambda d: d["item_number"].astype(int))
)

# %%
baseline_df.head()
# Out:
#    item_number                                      baseline_desc
# 0            1  Impact-branded photo backdrop kit including a ...
# 1            2  Interfit Stellar X flash lighting unit with ad...
# 2            3  Interfit Stellar X 300 studio strobe light wit...
# 3            4  Interfit Stellar X 300 studio flash unit equip...
# 4            5  Interfit COR 751 lighting kit with a wheeled c...

# %% [markdown]
# ## Merge into one df

# %%
both_descriptions = (
  baseline_df[["item_number", "baseline_desc"]]
  .merge(model_df[["item_number", "model_desc"]], on="item_number", how="left")
)
both_descriptions.head()
# Out:
#    item_number                                      baseline_desc  \
# 0            1  Impact-branded photo backdrop kit including a ...
# 1            2  Interfit Stellar X flash lighting unit with ad...
# 2            3  Interfit Stellar X 300 studio strobe light wit...
# 3            4  Interfit Stellar X 300 studio flash unit equip...
# 4            5  Interfit COR 751 lighting kit with a wheeled c...
#
#                                           model_desc
# 0  High-quality camera equipment set, including t...
# 1  Professional-grade INTERFIT Stellaro sound mod...
# 2  Professional-grade grey overhead projector wit...
# 3  Professional-grade Interfit Stellar 300 lighti...
# 4  Black circular cap with "INTERFIT" text in whi...

# %% [markdown]
# # Randomize the order of the model/baseline descriptions and keep track of the source

# %%
def randomize(row):
  # Each option: (column_name, description_text, source_label)
  options = [
    (row["model_desc"], "model"),
    (row["baseline_desc"], "baseline")
  ]
  random.shuffle(options)

  return pd.Series({
    "item_number": row["item_number"],
    "desc1": options[0][0],
    "desc1_source": options[0][1],
    "desc2": options[1][0],
    "desc2_source": options[1][1]
  })

# %%
test = both_descriptions.apply(randomize, axis=1)
test.head()
# Out:
#    item_number                                              desc1  \
# 0            1  High-quality camera equipment set, including t...
# 1            2  Professional-grade INTERFIT Stellaro sound mod...
# 2            3  Professional-grade grey overhead projector wit...
# 3            4  Interfit Stellar X 300 studio flash unit equip...
# 4            5  Black circular cap with "INTERFIT" text in whi...
#
#   desc1_source                                              desc2 desc2_source
# 0        model  Impact-branded photo backdrop kit including a ...     baseline
# 1        model  Interfit Stellar X flash lighting unit with ad...     baseline
# 2        model  Interfit Stellar X 300 studio strobe light wit...     baseline
# 3     baseline  Professional-grade Interfit Stellar 300 lighti...        model
# 4        model  Interfit COR 751 lighting kit with a wheeled c...     baseline

# %%
wrap_width = 80

def human_evaluation(row):
  print(f'Item number {row['item_number']}:')
  print("Description 1:")
  print(textwrap.fill(row["desc1"], width=wrap_width))
  print()

  print("Description 2:")
  print(textwrap.fill(row["desc2"], width=wrap_width))
  print()

  print("\nChoices:")
  print("1 = Description 1 better")
  print("2 = Description 2 better")
  print("3 = Both good")
  print("4 = Both bad")

  while True:
    choice = input("Your choice: ")
    if choice in {"1", "2", "3", "4"}:
      return int(choice)

# %%
def get_start_point(max_item = 60):
  while True:
    start_point = input(
      f"Choose an item number to start at (1 to {max_item}): "
    )

    # Handle non-integers gracefully
    if not start_point.isdigit():
      print("❌ Invalid input. Please enter a number.")
      continue

    start_point = int(start_point)

    # Check range
    if 1 <= start_point <= max_item:
      return start_point
    else:
      print(f"❌ Number out of range. Please choose between 1 and {max_item}.")

# %%
def evaluate_descriptions(df, max_items = 60):
  start_point = get_start_point()

  for item in range(start_point, max_items + 1):
    row = df[df['item_number'] == item].iloc[0]
    choice = human_evaluation(row)
    match choice:
      case 1:
        human_eval = row['desc1_source']
      case 2:
        human_eval = row['desc2_source']
      case 3:
        human_eval = 'Both descriptions are acceptable'
      case 4:
        human_eval = 'Both descriptions are unnacceptable'
      case _:
        human_eval = f'Error recording response for item {item}'

    df.loc[df['item_number'] == item, 'human_label'] = human_eval

    clear_output(wait=False)
    sleep(0.5)

  print(f'✅ Finished evaluating items')

# %%
evaluate_descriptions(test)
# Out:
# Item number 45:
# Description 1:
# Antique ornate rug with intricate floral and vine motifs in green, yellow, and
# beige on a cream background. Fringed edges, 5x8 feet. Handwoven in India, made
# from 100% wool. Ideal for vintage decor.
#
# Description 2:
# Handwoven wool rug from the Soumak Collection, Mahal 675 design, in a soft ivory
# field with intricate botanical motifs in muted greens, golds, and rust tones.
# Finished with fringe edges. Measures approximately 4 feet by 8 feet.
#
#
# Choices:
# 1 = Description 1 better
# 2 = Description 2 better
# 3 = Both good
# 4 = Both bad
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2678384443.py in <cell line: 0>()
# ----> 1 evaluate_descriptions(test)
#
# /tmp/ipython-input-3244092954.py in evaluate_descriptions(df, max_items)
#       6   for item in range(start_point, max_items + 1):
#       7     row = df[df['item_number'] == item].iloc[0]
# ----> 8     choice = human_evaluation(row)
#       9     match choice:
#      10       case 1:
#
# /tmp/ipython-input-1051084975.py in human_evaluation(row)
#      18
#      19   while True:
# ---> 20     choice = input("Your choice: ")
#      21     if choice in {"1", "2", "3", "4"}:
#      22       return int(choice)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
test
# Out:
#     item_number                                              desc1  \
# 0             1  Impact-branded photo backdrop kit including a ...
# 1             2  Interfit Stellar X flash lighting unit with ad...
# 2             3  Interfit Stellar X 300 studio strobe light wit...
# 3             4  Interfit Stellar X 300 studio flash unit equip...
# 4             5  Interfit COR 751 lighting kit with a wheeled c...
# 5             6  Pair of Impact floodlight fixtures mounted on ...
# 6             7  Assorted hand tool collection including Sears ...
# 7             8  Vintage set of metalworking tools and househol...
# 8             9  Clear plastic storage box containing a 4-1/2" ...
# 9            10  Heavy-duty Armstrong slide hammer puller set, ...
# 10           11  Pittsburgh Automotive Bearing Race and Seal Dr...
# 11           12  Set of Snap-on deep impact sockets stored in a...
# 12           13  Set of Craftsman hand tools including two comp...
# 13           14  Set of metallic, hexagonal nuts attached to a ...
# 14           15  Set of precision torque wrenches, featuring re...
# 15           16  Collection of measuring and leveling tools inc...
# 16           17  Pair of heavy-duty Haul-Master steel loading r...
# 17           18  High-quality, assembled machine with silver me...
# 18           19  Sculptural metal table lamp with welded abstra...
# 19           20  Antique brass and bronze floor lamp with a cyl...
# 20           21  Mid-century ceramic table lamp by Jacques Pouc...
# 21           22  Oil painting still life featuring a green wine...
# 22           23  Abstract astronomical painting by Airata Bouch...
# 23           24  Beautiful framed painting of a colorful sailbo...
# 24           25  Vibrant painting by M.VinLouis, featuring an e...
# 25           26  Colorful oil painting of a cobblestone street ...
# 26           27  Colorful market scene painting signed by M. V....
# 27           28  Two framed artworks: a black-and-white print w...
# 28           29  Round glass-top coffee table with a sculptural...
# 29           30  Vintage wooden folding table with metal frame,...
# 30           31  Antique brown hardwood chair with unique cut-o...
# 31           32  Modern art piece featuring a surreal, abstract...
# 32           33  Mid-century Drexel dresser with a sleek walnut...
# 33           34  Sturdy wooden furniture piece, featuring a rec...
# 34           35  Antique Grandfather clock featuring a rich, da...
# 35           36  Antique bronze hexagonal clock with brass dial...
# 36           37  Red Le Creuset terrine dish with a cream inter...
# 37           38  Antique-style, full-rigged, golden-hulled ship...
# 38           39  Green ceramic pitcher with carved leaf motif a...
# 39           40  Antique silver butterfly brooch featuring intr...
# 40           41  Mr. Coffee Café Barista espresso machine with ...
# 41           42  Set of three decorative swords, each marked “T...
# 42           43  Ornate handwoven area rug with a raised floral...
# 43           44  Hand-tufted Royal Ashan area rug by Downs Carp...
# 44           45  Antique ornate rug with intricate floral and v...
# 45           46  Vintage silver frying pans, featuring a reflec...
# 46           47  Towel Sterling silver flatware set in the 1973...
# 47           48  Pair of rectangular sterling silver military c...
# 48           49  Kenmore Elite electric dryer, model 110.669425...
# 49           50  Yellow boxed packaged goods featuring a sturdy...
# 50           51  Vintage Delta Industrial Machinery Corp. SAWBU...
# 51           52  Troy-Bilt 4-cycle gas-powered cultivator with ...
# 52           53  Snapper 22-inch self-propelled walk-behind mow...
# 53           54  Vintage, mint-green, plastic wall-mounted scon...
# 54           55  Vintage Bob Dylan album featuring iconic cover...
# 55           56  Husqvarna 136LE chainsaw powered by a 36cc 2-c...
# 56           57  Vintage Lionel train track set, featuring a va...
# 57           58  Open gray plastic tool box containing a green ...
# 58           59  A set of four used Continental ProContact TX t...
# 59           60  Vintage DeLonghi air heater with black and sil...
#
#    desc1_source                                              desc2  \
# 0      baseline  Professional photography equipment set featuri...
# 1      baseline  Electronic device with "INTERFIT" branding, mo...
# 2      baseline  Professional-grade grey overhead projector wit...
# 3      baseline  Electronic device, INTERFIT Stellar 300, small...
# 4      baseline  Round black hat with "INTERFIT" printed in whi...
# 5      baseline  Professional studio lighting kit featuring two...
# 6      baseline  Forged metalworking hand tools set, including ...
# 7         model  Box of assorted hand tools including multiple ...
# 8         model  Clear storage bin filled with grinding and cut...
# 9      baseline  Vintage metal tool with a wrapped, blue and wh...
# 10     baseline  Boxed Pittsburgh Bearing Race and Seal Driver ...
# 11     baseline  Set of plastic office instruments with cylindr...
# 12     baseline  Vintage CRAFTSMAN metalworking hand tools, inc...
# 13        model  Set of nine Proto Professional chrome sockets,...
# 14        model  Set of two torque wrenches from KD Tools and C...
# 15     baseline  Vintage measuring tools set, featuring a gold ...
# 16     baseline  Two silver steel loading ramps with 14 slots e...
# 17        model  Collection of Dyson V8 cordless vacuum parts a...
# 18     baseline  Vintage wall-mounted lamp with a beige, textur...
# 19        model  Tall mid-century lamp with stacked wood segmen...
# 20     baseline  Antique wicker cylinder lampshade paired with ...
# 21     baseline  Modern still life painting featuring a yellow ...
# 22        model  Original painting by Ronald Bouché depicting a...
# 23        model  Colorful seascape painting signed “Dany ’03” f...
# 24     baseline  Vibrant abstract painting featuring a chaotic ...
# 25     baseline  Vibrant watercolor painting depicting a snowy ...
# 26     baseline  A framed modern art piece depicting multiple i...
# 27        model  Framed satirical courtroom prints, including "...
# 28     baseline  Modern glass coffee table featuring sleek, nat...
# 29        model   Mobile teak table with chrome pedestal base a...
# 30        model  Mid-century modern lounge chair featuring scul...
# 31        model  Two ceramic tiles: one with a delicate pastel ...
# 32     baseline  Mid-century modern wooden bed frame featuring ...
# 33        model  Low-profile coffee table featuring a rectangul...
# 34        model  Tall wooden case clock with an arched bonnet a...
# 35        model  Gothic-style antique mantel clock with a dark ...
# 36     baseline  Vintage red and silver plastic wallet with a c...
# 37        model  Handcrafted model of the Mayflower marked “162...
# 38     baseline  Antique green ceramic pitcher with leaf patter...
# 39        model  Handcrafted metal angel wall hanging with intr...
# 40     baseline  Vintage Mr. Coffee café barista espresso machi...
# 41     baseline  Antique steel swords with ornate nickel handle...
# 42     baseline  Antique blue prayer rug with intricate yellow ...
# 43     baseline  Antique-style rug with intricate gold and blac...
# 44        model  Handwoven wool rug from the Soumak Collection,...
# 45        model  Set of three All-Clad stainless steel pans, in...
# 46     baseline  Vintage wooden cigar box with silver-toned met...
# 47     baseline  Vintage gray fabric with a vertical silver-ton...
# 48     baseline  White Kenmore Elite washing machine with push-...
# 49        model  CST/Berger Universal Contractor's Aluminum Tri...
# 50        model  Delta Sawbuck frame and trim saw, model 33-150...
# 51     baseline  Red walk-behind lawn mower with black handle a...
# 52     baseline  Used self-propelled lawn mower with red engine...
# 53        model  Pair of vintage metal mechanical banks designe...
# 54        model  Framed Bob Dylan collector's set featuring a l...
# 55     baseline  Husqvarna chainsaw, orange with gray handles, ...
# 56        model  Vintage Lionel Lines O-gauge electric train se...
# 57        model  Hitachi NT65MA2 2-1/2” finish nailer with angl...
# 58        model  Pair of Continental ProContact TX tires, size ...
# 59        model  Set of two space heaters including a LifeSmart...
#
#    desc2_source                       human_label
# 0         model  Both descriptions are acceptable
# 1         model                          baseline
# 2         model                          baseline
# 3         model                          baseline
# 4         model                          baseline
# 5         model  Both descriptions are acceptable
# 6         model                          baseline
# 7      baseline                          baseline
# 8      baseline  Both descriptions are acceptable
# 9         model                          baseline
# 10        model  Both descriptions are acceptable
# 11        model                          baseline
# 12        model  Both descriptions are acceptable
# 13     baseline                          baseline
# 14     baseline  Both descriptions are acceptable
# 15        model  Both descriptions are acceptable
# 16        model  Both descriptions are acceptable
# 17     baseline                          baseline
# 18        model                          baseline
# 19     baseline                          baseline
# 20        model                          baseline
# 21        model  Both descriptions are acceptable
# 22     baseline                          baseline
# 23     baseline  Both descriptions are acceptable
# 24        model                          baseline
# 25        model                          baseline
# 26        model                             model
# 27     baseline                          baseline
# 28        model  Both descriptions are acceptable
# 29     baseline                          baseline
# 30     baseline                          baseline
# 31     baseline                          baseline
# 32        model                          baseline
# 33     baseline                          baseline
# 34     baseline                             model
# 35     baseline                          baseline
# 36        model                          baseline
# 37     baseline                             model
# 38        model                             model
# 39     baseline                          baseline
# 40        model  Both descriptions are acceptable
# 41        model  Both descriptions are acceptable
# 42        model                          baseline
# 43        model  Both descriptions are acceptable
# 44     baseline                             model
# 45     baseline  Both descriptions are acceptable
# 46        model                          baseline
# 47        model                          baseline
# 48        model  Both descriptions are acceptable
# 49     baseline                          baseline
# 50     baseline  Both descriptions are acceptable
# 51        model                          baseline
# 52        model                          baseline
# 53     baseline                          baseline
# 54     baseline                          baseline
# 55        model  Both descriptions are acceptable
# 56     baseline  Both descriptions are acceptable
# 57     baseline                          baseline
# 58     baseline  Both descriptions are acceptable
# 59     baseline                          baseline

# %%
test.to_csv('Aypt2025-13_evaluated.csv', index=False)

# %%
test
# Out:
#     item_number                                              desc1  \
# 0             1  Impact-branded photo backdrop kit including a ...
# 1             2  Interfit Stellar X flash lighting unit with ad...
# 2             3  Interfit Stellar X 300 studio strobe light wit...
# 3             4  Interfit Stellar X 300 studio flash unit equip...
# 4             5  Interfit COR 751 lighting kit with a wheeled c...
# 5             6  Pair of Impact floodlight fixtures mounted on ...
# 6             7  Assorted hand tool collection including Sears ...
# 7             8  Vintage set of metalworking tools and househol...
# 8             9  Clear plastic storage box containing a 4-1/2" ...
# 9            10  Heavy-duty Armstrong slide hammer puller set, ...
# 10           11  Pittsburgh Automotive Bearing Race and Seal Dr...
# 11           12  Set of Snap-on deep impact sockets stored in a...
# 12           13  Set of Craftsman hand tools including two comp...
# 13           14  Set of metallic, hexagonal nuts attached to a ...
# 14           15  Set of precision torque wrenches, featuring re...
# 15           16  Collection of measuring and leveling tools inc...
# 16           17  Pair of heavy-duty Haul-Master steel loading r...
# 17           18  High-quality, assembled machine with silver me...
# 18           19  Sculptural metal table lamp with welded abstra...
# 19           20  Antique brass and bronze floor lamp with a cyl...
# 20           21  Mid-century ceramic table lamp by Jacques Pouc...
# 21           22  Oil painting still life featuring a green wine...
# 22           23  Abstract astronomical painting by Airata Bouch...
# 23           24  Beautiful framed painting of a colorful sailbo...
# 24           25  Vibrant painting by M.VinLouis, featuring an e...
# 25           26  Colorful oil painting of a cobblestone street ...
# 26           27  Colorful market scene painting signed by M. V....
# 27           28  Two framed artworks: a black-and-white print w...
# 28           29  Round glass-top coffee table with a sculptural...
# 29           30  Vintage wooden folding table with metal frame,...
# 30           31  Antique brown hardwood chair with unique cut-o...
# 31           32  Modern art piece featuring a surreal, abstract...
# 32           33  Mid-century Drexel dresser with a sleek walnut...
# 33           34  Sturdy wooden furniture piece, featuring a rec...
# 34           35  Antique Grandfather clock featuring a rich, da...
# 35           36  Antique bronze hexagonal clock with brass dial...
# 36           37  Red Le Creuset terrine dish with a cream inter...
# 37           38  Antique-style, full-rigged, golden-hulled ship...
# 38           39  Green ceramic pitcher with carved leaf motif a...
# 39           40  Antique silver butterfly brooch featuring intr...
# 40           41  Mr. Coffee Café Barista espresso machine with ...
# 41           42  Set of three decorative swords, each marked “T...
# 42           43  Ornate handwoven area rug with a raised floral...
# 43           44  Hand-tufted Royal Ashan area rug by Downs Carp...
# 44           45  Antique ornate rug with intricate floral and v...
# 45           46  Vintage silver frying pans, featuring a reflec...
# 46           47  Towel Sterling silver flatware set in the 1973...
# 47           48  Pair of rectangular sterling silver military c...
# 48           49  Kenmore Elite electric dryer, model 110.669425...
# 49           50  Yellow boxed packaged goods featuring a sturdy...
# 50           51  Vintage Delta Industrial Machinery Corp. SAWBU...
# 51           52  Troy-Bilt 4-cycle gas-powered cultivator with ...
# 52           53  Snapper 22-inch self-propelled walk-behind mow...
# 53           54  Vintage, mint-green, plastic wall-mounted scon...
# 54           55  Vintage Bob Dylan album featuring iconic cover...
# 55           56  Husqvarna 136LE chainsaw powered by a 36cc 2-c...
# 56           57  Vintage Lionel train track set, featuring a va...
# 57           58  Open gray plastic tool box containing a green ...
# 58           59  A set of four used Continental ProContact TX t...
# 59           60  Vintage DeLonghi air heater with black and sil...
#
#    desc1_source                                              desc2  \
# 0      baseline  Professional photography equipment set featuri...
# 1      baseline  Electronic device with "INTERFIT" branding, mo...
# 2      baseline  Professional-grade grey overhead projector wit...
# 3      baseline  Electronic device, INTERFIT Stellar 300, small...
# 4      baseline  Round black hat with "INTERFIT" printed in whi...
# 5      baseline  Professional studio lighting kit featuring two...
# 6      baseline  Forged metalworking hand tools set, including ...
# 7         model  Box of assorted hand tools including multiple ...
# 8         model  Clear storage bin filled with grinding and cut...
# 9      baseline  Vintage metal tool with a wrapped, blue and wh...
# 10     baseline  Boxed Pittsburgh Bearing Race and Seal Driver ...
# 11     baseline  Set of plastic office instruments with cylindr...
# 12     baseline  Vintage CRAFTSMAN metalworking hand tools, inc...
# 13        model  Set of nine Proto Professional chrome sockets,...
# 14        model  Set of two torque wrenches from KD Tools and C...
# 15     baseline  Vintage measuring tools set, featuring a gold ...
# 16     baseline  Two silver steel loading ramps with 14 slots e...
# 17        model  Collection of Dyson V8 cordless vacuum parts a...
# 18     baseline  Vintage wall-mounted lamp with a beige, textur...
# 19        model  Tall mid-century lamp with stacked wood segmen...
# 20     baseline  Antique wicker cylinder lampshade paired with ...
# 21     baseline  Modern still life painting featuring a yellow ...
# 22        model  Original painting by Ronald Bouché depicting a...
# 23        model  Colorful seascape painting signed “Dany ’03” f...
# 24     baseline  Vibrant abstract painting featuring a chaotic ...
# 25     baseline  Vibrant watercolor painting depicting a snowy ...
# 26     baseline  A framed modern art piece depicting multiple i...
# 27        model  Framed satirical courtroom prints, including "...
# 28     baseline  Modern glass coffee table featuring sleek, nat...
# 29        model   Mobile teak table with chrome pedestal base a...
# 30        model  Mid-century modern lounge chair featuring scul...
# 31        model  Two ceramic tiles: one with a delicate pastel ...
# 32     baseline  Mid-century modern wooden bed frame featuring ...
# 33        model  Low-profile coffee table featuring a rectangul...
# 34        model  Tall wooden case clock with an arched bonnet a...
# 35        model  Gothic-style antique mantel clock with a dark ...
# 36     baseline  Vintage red and silver plastic wallet with a c...
# 37        model  Handcrafted model of the Mayflower marked “162...
# 38     baseline  Antique green ceramic pitcher with leaf patter...
# 39        model  Handcrafted metal angel wall hanging with intr...
# 40     baseline  Vintage Mr. Coffee café barista espresso machi...
# 41     baseline  Antique steel swords with ornate nickel handle...
# 42     baseline  Antique blue prayer rug with intricate yellow ...
# 43     baseline  Antique-style rug with intricate gold and blac...
# 44        model  Handwoven wool rug from the Soumak Collection,...
# 45        model  Set of three All-Clad stainless steel pans, in...
# 46     baseline  Vintage wooden cigar box with silver-toned met...
# 47     baseline  Vintage gray fabric with a vertical silver-ton...
# 48     baseline  White Kenmore Elite washing machine with push-...
# 49        model  CST/Berger Universal Contractor's Aluminum Tri...
# 50        model  Delta Sawbuck frame and trim saw, model 33-150...
# 51     baseline  Red walk-behind lawn mower with black handle a...
# 52     baseline  Used self-propelled lawn mower with red engine...
# 53        model  Pair of vintage metal mechanical banks designe...
# 54        model  Framed Bob Dylan collector's set featuring a l...
# 55     baseline  Husqvarna chainsaw, orange with gray handles, ...
# 56        model  Vintage Lionel Lines O-gauge electric train se...
# 57        model  Hitachi NT65MA2 2-1/2” finish nailer with angl...
# 58        model  Pair of Continental ProContact TX tires, size ...
# 59        model  Set of two space heaters including a LifeSmart...
#
#    desc2_source                       human_label
# 0         model  Both descriptions are acceptable
# 1         model                          baseline
# 2         model                          baseline
# 3         model                          baseline
# 4         model                          baseline
# 5         model  Both descriptions are acceptable
# 6         model                          baseline
# 7      baseline                          baseline
# 8      baseline  Both descriptions are acceptable
# 9         model                          baseline
# 10        model  Both descriptions are acceptable
# 11        model                          baseline
# 12        model  Both descriptions are acceptable
# 13     baseline                          baseline
# 14     baseline  Both descriptions are acceptable
# 15        model  Both descriptions are acceptable
# 16        model  Both descriptions are acceptable
# 17     baseline                          baseline
# 18        model                          baseline
# 19     baseline                          baseline
# 20        model                          baseline
# 21        model  Both descriptions are acceptable
# 22     baseline                          baseline
# 23     baseline  Both descriptions are acceptable
# 24        model                          baseline
# 25        model                          baseline
# 26        model                             model
# 27     baseline                          baseline
# 28        model  Both descriptions are acceptable
# 29     baseline                          baseline
# 30     baseline                          baseline
# 31     baseline                          baseline
# 32        model                          baseline
# 33     baseline                          baseline
# 34     baseline                             model
# 35     baseline                          baseline
# 36        model                          baseline
# 37     baseline                             model
# 38        model                             model
# 39     baseline                          baseline
# 40        model  Both descriptions are acceptable
# 41        model  Both descriptions are acceptable
# 42        model                          baseline
# 43        model  Both descriptions are acceptable
# 44     baseline                             model
# 45     baseline  Both descriptions are acceptable
# 46        model                          baseline
# 47        model                          baseline
# 48        model  Both descriptions are acceptable
# 49     baseline                          baseline
# 50     baseline  Both descriptions are acceptable
# 51        model                          baseline
# 52        model                          baseline
# 53     baseline                          baseline
# 54     baseline                          baseline
# 55        model  Both descriptions are acceptable
# 56     baseline  Both descriptions are acceptable
# 57     baseline                          baseline
# 58     baseline  Both descriptions are acceptable
# 59     baseline                          baseline

# %% [markdown]
# # Final Evaluation

# %%
df1 = pd.read_csv('Aypt2025-13_evaluated.csv')
df2 = pd.read_csv('auction_13_descriptions_categories.csv', index_col=0)

eval = pd.merge(df1, df2.drop(columns=['Description'], axis=1), how='left', on='item_number')

# %%
eval.head()
# Out:
#    item_number                                              desc1  \
# 0            1  Impact-branded photo backdrop kit including a ...
# 1            2  Interfit Stellar X flash lighting unit with ad...
# 2            3  Interfit Stellar X 300 studio strobe light wit...
# 3            4  Interfit Stellar X 300 studio flash unit equip...
# 4            5  Interfit COR 751 lighting kit with a wheeled c...
#
#   desc1_source                                              desc2  \
# 0     baseline  Professional photography equipment set featuri...
# 1     baseline  Electronic device with "INTERFIT" branding, mo...
# 2     baseline  Professional-grade grey overhead projector wit...
# 3     baseline  Electronic device, INTERFIT Stellar 300, small...
# 4     baseline  Round black hat with "INTERFIT" printed in whi...
#
#   desc2_source                       human_label               category
# 0        model  Both descriptions are acceptable  Photography Equipment
# 1        model                          baseline  Photography Equipment
# 2        model                          baseline  Photography Equipment
# 3        model                          baseline  Photography Equipment
# 4        model                          baseline  Photography Equipment

# %%
sns.countplot(eval['human_label'])
# Out:
# <Axes: xlabel='count', ylabel='human_label'>

# %%
label_counts = eval['human_label'].value_counts()
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%')
plt.show()

# %%
category_counts = eval['category'].value_counts()
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.show()

# %%
infrequent_indexes = eval['category'].value_counts()[lambda x: x <= 2].index
eval['category_grouped'] = eval['category'].replace(infrequent_indexes, 'Other')

# %%
eval
# Out:
#     item_number                                              desc1  \
# 0             1  Impact-branded photo backdrop kit including a ...
# 1             2  Interfit Stellar X flash lighting unit with ad...
# 2             3  Interfit Stellar X 300 studio strobe light wit...
# 3             4  Interfit Stellar X 300 studio flash unit equip...
# 4             5  Interfit COR 751 lighting kit with a wheeled c...
# 5             6  Pair of Impact floodlight fixtures mounted on ...
# 6             7  Assorted hand tool collection including Sears ...
# 7             8  Vintage set of metalworking tools and househol...
# 8             9  Clear plastic storage box containing a 4-1/2" ...
# 9            10  Heavy-duty Armstrong slide hammer puller set, ...
# 10           11  Pittsburgh Automotive Bearing Race and Seal Dr...
# 11           12  Set of Snap-on deep impact sockets stored in a...
# 12           13  Set of Craftsman hand tools including two comp...
# 13           14  Set of metallic, hexagonal nuts attached to a ...
# 14           15  Set of precision torque wrenches, featuring re...
# 15           16  Collection of measuring and leveling tools inc...
# 16           17  Pair of heavy-duty Haul-Master steel loading r...
# 17           18  High-quality, assembled machine with silver me...
# 18           19  Sculptural metal table lamp with welded abstra...
# 19           20  Antique brass and bronze floor lamp with a cyl...
# 20           21  Mid-century ceramic table lamp by Jacques Pouc...
# 21           22  Oil painting still life featuring a green wine...
# 22           23  Abstract astronomical painting by Airata Bouch...
# 23           24  Beautiful framed painting of a colorful sailbo...
# 24           25  Vibrant painting by M.VinLouis, featuring an e...
# 25           26  Colorful oil painting of a cobblestone street ...
# 26           27  Colorful market scene painting signed by M. V....
# 27           28  Two framed artworks: a black-and-white print w...
# 28           29  Round glass-top coffee table with a sculptural...
# 29           30  Vintage wooden folding table with metal frame,...
# 30           31  Antique brown hardwood chair with unique cut-o...
# 31           32  Modern art piece featuring a surreal, abstract...
# 32           33  Mid-century Drexel dresser with a sleek walnut...
# 33           34  Sturdy wooden furniture piece, featuring a rec...
# 34           35  Antique Grandfather clock featuring a rich, da...
# 35           36  Antique bronze hexagonal clock with brass dial...
# 36           37  Red Le Creuset terrine dish with a cream inter...
# 37           38  Antique-style, full-rigged, golden-hulled ship...
# 38           39  Green ceramic pitcher with carved leaf motif a...
# 39           40  Antique silver butterfly brooch featuring intr...
# 40           41  Mr. Coffee Café Barista espresso machine with ...
# 41           42  Set of three decorative swords, each marked “T...
# 42           43  Ornate handwoven area rug with a raised floral...
# 43           44  Hand-tufted Royal Ashan area rug by Downs Carp...
# 44           45  Antique ornate rug with intricate floral and v...
# 45           46  Vintage silver frying pans, featuring a reflec...
# 46           47  Towel Sterling silver flatware set in the 1973...
# 47           48  Pair of rectangular sterling silver military c...
# 48           49  Kenmore Elite electric dryer, model 110.669425...
# 49           50  Yellow boxed packaged goods featuring a sturdy...
# 50           51  Vintage Delta Industrial Machinery Corp. SAWBU...
# 51           52  Troy-Bilt 4-cycle gas-powered cultivator with ...
# 52           53  Snapper 22-inch self-propelled walk-behind mow...
# 53           54  Vintage, mint-green, plastic wall-mounted scon...
# 54           55  Vintage Bob Dylan album featuring iconic cover...
# 55           56  Husqvarna 136LE chainsaw powered by a 36cc 2-c...
# 56           57  Vintage Lionel train track set, featuring a va...
# 57           58  Open gray plastic tool box containing a green ...
# 58           59  A set of four used Continental ProContact TX t...
# 59           60  Vintage DeLonghi air heater with black and sil...
#
#    desc1_source                                              desc2  \
# 0      baseline  Professional photography equipment set featuri...
# 1      baseline  Electronic device with "INTERFIT" branding, mo...
# 2      baseline  Professional-grade grey overhead projector wit...
# 3      baseline  Electronic device, INTERFIT Stellar 300, small...
# 4      baseline  Round black hat with "INTERFIT" printed in whi...
# 5      baseline  Professional studio lighting kit featuring two...
# 6      baseline  Forged metalworking hand tools set, including ...
# 7         model  Box of assorted hand tools including multiple ...
# 8         model  Clear storage bin filled with grinding and cut...
# 9      baseline  Vintage metal tool with a wrapped, blue and wh...
# 10     baseline  Boxed Pittsburgh Bearing Race and Seal Driver ...
# 11     baseline  Set of plastic office instruments with cylindr...
# 12     baseline  Vintage CRAFTSMAN metalworking hand tools, inc...
# 13        model  Set of nine Proto Professional chrome sockets,...
# 14        model  Set of two torque wrenches from KD Tools and C...
# 15     baseline  Vintage measuring tools set, featuring a gold ...
# 16     baseline  Two silver steel loading ramps with 14 slots e...
# 17        model  Collection of Dyson V8 cordless vacuum parts a...
# 18     baseline  Vintage wall-mounted lamp with a beige, textur...
# 19        model  Tall mid-century lamp with stacked wood segmen...
# 20     baseline  Antique wicker cylinder lampshade paired with ...
# 21     baseline  Modern still life painting featuring a yellow ...
# 22        model  Original painting by Ronald Bouché depicting a...
# 23        model  Colorful seascape painting signed “Dany ’03” f...
# 24     baseline  Vibrant abstract painting featuring a chaotic ...
# 25     baseline  Vibrant watercolor painting depicting a snowy ...
# 26     baseline  A framed modern art piece depicting multiple i...
# 27        model  Framed satirical courtroom prints, including "...
# 28     baseline  Modern glass coffee table featuring sleek, nat...
# 29        model   Mobile teak table with chrome pedestal base a...
# 30        model  Mid-century modern lounge chair featuring scul...
# 31        model  Two ceramic tiles: one with a delicate pastel ...
# 32     baseline  Mid-century modern wooden bed frame featuring ...
# 33        model  Low-profile coffee table featuring a rectangul...
# 34        model  Tall wooden case clock with an arched bonnet a...
# 35        model  Gothic-style antique mantel clock with a dark ...
# 36     baseline  Vintage red and silver plastic wallet with a c...
# 37        model  Handcrafted model of the Mayflower marked “162...
# 38     baseline  Antique green ceramic pitcher with leaf patter...
# 39        model  Handcrafted metal angel wall hanging with intr...
# 40     baseline  Vintage Mr. Coffee café barista espresso machi...
# 41     baseline  Antique steel swords with ornate nickel handle...
# 42     baseline  Antique blue prayer rug with intricate yellow ...
# 43     baseline  Antique-style rug with intricate gold and blac...
# 44        model  Handwoven wool rug from the Soumak Collection,...
# 45        model  Set of three All-Clad stainless steel pans, in...
# 46     baseline  Vintage wooden cigar box with silver-toned met...
# 47     baseline  Vintage gray fabric with a vertical silver-ton...
# 48     baseline  White Kenmore Elite washing machine with push-...
# 49        model  CST/Berger Universal Contractor's Aluminum Tri...
# 50        model  Delta Sawbuck frame and trim saw, model 33-150...
# 51     baseline  Red walk-behind lawn mower with black handle a...
# 52     baseline  Used self-propelled lawn mower with red engine...
# 53        model  Pair of vintage metal mechanical banks designe...
# 54        model  Framed Bob Dylan collector's set featuring a l...
# 55     baseline  Husqvarna chainsaw, orange with gray handles, ...
# 56        model  Vintage Lionel Lines O-gauge electric train se...
# 57        model  Hitachi NT65MA2 2-1/2” finish nailer with angl...
# 58        model  Pair of Continental ProContact TX tires, size ...
# 59        model  Set of two space heaters including a LifeSmart...
#
#    desc2_source                       human_label                category  \
# 0         model  Both descriptions are acceptable   Photography Equipment
# 1         model                          baseline   Photography Equipment
# 2         model                          baseline   Photography Equipment
# 3         model                          baseline   Photography Equipment
# 4         model                          baseline   Photography Equipment
# 5         model  Both descriptions are acceptable   Photography Equipment
# 6         model                          baseline                   Tools
# 7      baseline                          baseline                   Tools
# 8      baseline  Both descriptions are acceptable                   Tools
# 9         model                          baseline                   Tools
# 10        model  Both descriptions are acceptable                   Tools
# 11        model                          baseline                   Tools
# 12        model  Both descriptions are acceptable                   Tools
# 13     baseline                          baseline                   Tools
# 14     baseline  Both descriptions are acceptable                   Tools
# 15        model  Both descriptions are acceptable                   Tools
# 16        model  Both descriptions are acceptable                   Tools
# 17     baseline                          baseline                   Tools
# 18        model                          baseline                Lighting
# 19     baseline                          baseline                Lighting
# 20        model                          baseline                Lighting
# 21        model  Both descriptions are acceptable                     Art
# 22     baseline                          baseline                     Art
# 23     baseline  Both descriptions are acceptable                     Art
# 24        model                          baseline                     Art
# 25        model                          baseline                     Art
# 26        model                             model                     Art
# 27     baseline                          baseline                     Art
# 28        model  Both descriptions are acceptable               Furniture
# 29     baseline                          baseline               Furniture
# 30     baseline                          baseline               Furniture
# 31     baseline                          baseline                     Art
# 32        model                          baseline               Furniture
# 33     baseline                          baseline               Furniture
# 34     baseline                             model                  Clocks
# 35     baseline                          baseline                  Clocks
# 36        model                          baseline                Cookware
# 37     baseline                             model            Collectibles
# 38        model                             model                     Art
# 39     baseline                          baseline              Decorative
# 40        model  Both descriptions are acceptable       Kitchen Appliance
# 41        model  Both descriptions are acceptable       Decorative Swords
# 42        model                          baseline                    Rugs
# 43        model  Both descriptions are acceptable                    Rugs
# 44     baseline                             model                    Rugs
# 45     baseline  Both descriptions are acceptable                Cookware
# 46        model                          baseline                Flatware
# 47        model                          baseline                 Jewelry
# 48        model  Both descriptions are acceptable              Appliances
# 49     baseline                          baseline  Construction Equipment
# 50     baseline  Both descriptions are acceptable                   Tools
# 51        model                          baseline            Garden Tools
# 52        model                          baseline             Lawn Mowers
# 53     baseline                          baseline            Collectibles
# 54     baseline                          baseline            Collectibles
# 55        model  Both descriptions are acceptable                   Tools
# 56     baseline  Both descriptions are acceptable               Train Set
# 57     baseline                          baseline                   Tools
# 58     baseline  Both descriptions are acceptable                   Tires
# 59     baseline                          baseline       Heating Equipment
#
#          category_grouped
# 0   Photography Equipment
# 1   Photography Equipment
# 2   Photography Equipment
# 3   Photography Equipment
# 4   Photography Equipment
# 5   Photography Equipment
# 6                   Tools
# 7                   Tools
# 8                   Tools
# 9                   Tools
# 10                  Tools
# 11                  Tools
# 12                  Tools
# 13                  Tools
# 14                  Tools
# 15                  Tools
# 16                  Tools
# 17                  Tools
# 18               Lighting
# 19               Lighting
# 20               Lighting
# 21                    Art
# 22                    Art
# 23                    Art
# 24                    Art
# 25                    Art
# 26                    Art
# 27                    Art
# 28              Furniture
# 29              Furniture
# 30              Furniture
# 31                    Art
# 32              Furniture
# 33              Furniture
# 34                  Other
# 35                  Other
# 36                  Other
# 37           Collectibles
# 38                    Art
# 39                  Other
# 40                  Other
# 41                  Other
# 42                   Rugs
# 43                   Rugs
# 44                   Rugs
# 45                  Other
# 46                  Other
# 47                  Other
# 48                  Other
# 49                  Other
# 50                  Tools
# 51                  Other
# 52                  Other
# 53           Collectibles
# 54           Collectibles
# 55                  Tools
# 56                  Other
# 57                  Tools
# 58                  Other
# 59                  Other

# %%
eval['category_grouped'].value_counts()
# Out:
# category_grouped
# Other                    16
# Tools                    15
# Art                       9
# Photography Equipment     6
# Furniture                 5
# Lighting                  3
# Collectibles              3
# Rugs                      3
# Name: count, dtype: int64
